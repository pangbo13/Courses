# %% [markdown]
# # Simulations Episode Scraper Match Downloader

# %% [markdown]
# This notebook downloads episodes using Kaggle's GetEpisodeReplay API and the [Meta Kaggle](https://www.kaggle.com/kaggle/meta-kaggle) dataset.
#
# **To run this notebook you WILL need to re-add the Meta Kaggle dataset. After opening your copy of the notebook, click "+ Add data" top right in the notebook editor.
# **
#
# Meta Kaggle is refreshed daily, but sometimes misses daily refreshes for a few days.
#
# Why download replays?
# - Train your ML/RL model
# - Inspect the performance of yours and others agents
# - To add to your ever growing json collection
#
# Only one scraping strategy is implemented: For each top scoring submission, download all missing matches, move on to next submission.
#
# Other scraping strategies can be implemented, but not here. Like download max X matches per submission or per team per day, or ignore certain teams or ignore where some scores < X, or only download some teams.
#
# Todo:
# - Add teamid's once meta kaggle add them. Edit: it's been a long time, it doesn't look like Kaggle is adding this.

# %%
import pandas as pd
import numpy as np
import os
import requests
import json
import datetime
import time
import glob
import collections

# %%
## You should configure these to your needs. Choose one of ...
# 'hungry-geese', 'rock-paper-scissors', santa-2020', 'halite', 'google-football'
COMP = 'lux-ai-2021'
MAX_CALLS_PER_DAY = 1000 # Kaggle says don't do more than 3600 per day and 1 per second
LOWEST_SCORE_THRESH = 2000

# %%
ROOT ="../working/"
META = "../input/meta-kaggle/"
MATCH_DIR = '../working/'
base_url = "https://www.kaggle.com/requests/EpisodeService/"
get_url = base_url + "GetEpisodeReplay"
BUFFER = 1
COMPETITIONS = {
    'lux-ai-2021': 30067,
    'hungry-geese': 25401,
    'rock-paper-scissors': 22838,
    'santa-2020': 24539,
    'halite': 18011,
    'google-football': 21723
}

# %%
# Load Episodes
episodes_df = pd.read_csv(META + "Episodes.csv")

# Load EpisodeAgents
epagents_df = pd.read_csv(META + "EpisodeAgents.csv")

print(f'Episodes.csv: {len(episodes_df)} rows before filtering.')
print(f'EpisodeAgents.csv: {len(epagents_df)} rows before filtering.')

episodes_df = episodes_df[episodes_df.CompetitionId == COMPETITIONS[COMP]] 
epagents_df = epagents_df[epagents_df.EpisodeId.isin(episodes_df.Id)]

print(f'Episodes.csv: {len(episodes_df)} rows after filtering for {COMP}.')
print(f'EpisodeAgents.csv: {len(epagents_df)} rows after filtering for {COMP}.')
# Out:
# Episodes.csv: 32046986 rows before filtering.
# EpisodeAgents.csv: 79157036 rows before filtering.
# Episodes.csv: 5317724 rows after filtering for lux-ai-2021.
# EpisodeAgents.csv: 10635448 rows after filtering for lux-ai-2021.

# %%
# Prepare dataframes

episodes_df = episodes_df.set_index(['Id'])
episodes_df['CreateTime'] = pd.to_datetime(episodes_df['CreateTime'])
episodes_df['EndTime'] = pd.to_datetime(episodes_df['EndTime'])

epagents_df.fillna(0, inplace=True)
epagents_df = epagents_df.sort_values(by=['Id'], ascending=False)

# %%
# Get top scoring submissions# Get top scoring submissions
max_df = (epagents_df.sort_values(by=['EpisodeId'], ascending=False).groupby('SubmissionId').head(1).drop_duplicates().reset_index(drop=True))
max_df = max_df[max_df.UpdatedScore>=LOWEST_SCORE_THRESH]
max_df = pd.merge(left=episodes_df, right=max_df, left_on='Id', right_on='EpisodeId')
sub_to_score_top = pd.Series(max_df.UpdatedScore.values,index=max_df.SubmissionId).to_dict()
print(f'{len(sub_to_score_top)} submissions with score over {LOWEST_SCORE_THRESH}')
print(sub_to_score_top)
# Out:
# 2 submissions with score over 2000
# {23692494: 2013.9246716539203, 23281649: 2004.3788394987848}

# %%
# Get episodes for these submissions
sub_to_episodes = collections.defaultdict(list)
for key, value in sorted(sub_to_score_top.items(), key=lambda kv: kv[1], reverse=True):
    excl = []
    if key not in excl: # we can filter subs like this
        eps = sorted(epagents_df[epagents_df['SubmissionId'].isin([key])]['EpisodeId'].values,reverse=True)
        sub_to_episodes[key] = eps
candidates = len(set([item for sublist in sub_to_episodes.values() for item in sublist]))
print(f'{candidates} episodes for these {len(sub_to_score_top)} submissions')
# Out:
# 663 episodes for these 2 submissions

# %%
global num_api_calls_today
num_api_calls_today = 0
all_files = []
for root, dirs, files in os.walk(MATCH_DIR, topdown=False):
    all_files.extend(files)
seen_episodes = [int(f.split('.')[0]) for f in all_files 
                      if '.' in f and f.split('.')[0].isdigit() and f.split('.')[1] == 'json']
remaining = np.setdiff1d([item for sublist in sub_to_episodes.values() for item in sublist],seen_episodes)
print(f'{len(remaining)} of these {candidates} episodes not yet saved')
print('Total of {} games in existing library'.format(len(seen_episodes)))
# Out:
# 663 of these 663 episodes not yet saved
# Total of 0 games in existing library

# %%
def create_info_json(epid):
    
    create_seconds = int((episodes_df[episodes_df.index == epid]['CreateTime'].values[0]).item()/1e9)
    end_seconds = int((episodes_df[episodes_df.index == epid]['CreateTime'].values[0]).item()/1e9)

    agents = []
    for index, row in epagents_df[epagents_df['EpisodeId'] == epid].sort_values(by=['Index']).iterrows():
        agent = {
            "id": int(row["Id"]),
            "state": int(row["State"]),
            "submissionId": int(row['SubmissionId']),
            "reward": int(row['Reward']),
            "index": int(row['Index']),
            "initialScore": float(row['InitialScore']),
            "initialConfidence": float(row['InitialConfidence']),
            "updatedScore": float(row['UpdatedScore']),
            "updatedConfidence": float(row['UpdatedConfidence']),
            "teamId": int(99999)
        }
        agents.append(agent)

    info = {
        "id": int(epid),
        "competitionId": int(COMPETITIONS[COMP]),
        "createTime": {
            "seconds": int(create_seconds)
        },
        "endTime": {
            "seconds": int(end_seconds)
        },
        "agents": agents
    }

    return info

# %%
def saveEpisode(epid):
    # request
    re = requests.post(get_url, json = {"EpisodeId": int(epid)})
        
    # save replay
    with open(MATCH_DIR + '{}.json'.format(epid), 'w') as f:
        f.write(re.json()['result']['replay'])

    # save match info
#     info = create_info_json(epid)
#     with open(MATCH_DIR +  '{}_info.json'.format(epid), 'w') as f:
#         json.dump(info, f)

# %%
r = BUFFER;

start_time = datetime.datetime.now()
se=0
for key, value in sorted(sub_to_score_top.items(), key=lambda kv: kv[1], reverse=True):
    if num_api_calls_today<=MAX_CALLS_PER_DAY:
        print('')
        remaining = sorted(np.setdiff1d(sub_to_episodes[key],seen_episodes), reverse=True)
        print(f'submission={key}, LB={"{:.0f}".format(value)}, matches={len(set(sub_to_episodes[key]))}, still to save={len(remaining)}')
        
        for epid in remaining:
            if epid not in seen_episodes and num_api_calls_today<=MAX_CALLS_PER_DAY:
                saveEpisode(epid); 
                r+=1;
                se+=1
                try:
                    size = os.path.getsize(MATCH_DIR+'{}.json'.format(epid)) / 1e6
                    print(str(num_api_calls_today) + f': saved episode #{epid}')
                    seen_episodes.append(epid)
                    num_api_calls_today+=1
                except:
                    print('  file {}.json did not seem to save'.format(epid))    
                if r > (datetime.datetime.now() - start_time).seconds:
                    time.sleep( r - (datetime.datetime.now() - start_time).seconds)
            if num_api_calls_today>(min(3600,MAX_CALLS_PER_DAY)):
                break
print('')
print(f'Episodes saved: {se}')
# Out:
# submission=23692494, LB=2014, matches=231, still to save=231
# 0: saved episode #32161015
# 1: saved episode #32147352
# 2: saved episode #32133407
# 3: saved episode #32119052
# 4: saved episode #32105261
# 5: saved episode #32091340
# 6: saved episode #32077535
# 7: saved episode #32063788
# 8: saved episode #32049262
# 9: saved episode #32035085
# 10: saved episode #32021292
# 11: saved episode #32007031
# 12: saved episode #31992519
# 13: saved episode #31978847
# 14: saved episode #31964987
# 15: saved episode #31951440
# 16: saved episode #31938237
# 17: saved episode #31924186
# 18: saved episode #31910337
# 19: saved episode #31896868
# 20: saved episode #31883080
# 21: saved episode #31869552
# 22: saved episode #31856291
# 23: saved episode #31843202
# 24: saved episode #31829802
# 25: saved episode #31816410
# 26: saved episode #31802516
# 27: saved episode #31789295
# 28: saved episode #31776766
# 29: saved episode #31763549
# 30: saved episode #31750122
# 31: saved episode #31736953
# 32: saved episode #31723624
# 33: saved episode #31710140
# 34: saved episode #31696679
# 35: saved episode #31683203
# 36: saved episode #31669633
# 37: saved episode #31656432
# 38: saved episode #31643003
# 39: saved episode #31630276
# 40: saved episode #31617784
# 41: saved episode #31605069
# 42: saved episode #31592167
# 43: saved episode #31578953
# 44: saved episode #31565932
# 45: saved episode #31553160
# 46: saved episode #31540597
# 47: saved episode #31527480
# 48: saved episode #31514474
# 49: saved episode #31501689
# 50: saved episode #31488821
# 51: saved episode #31488820
# 52: saved episode #31476309
# 53: saved episode #31463974
# 54: saved episode #31451116
# 55: saved episode #31439960
# 56: saved episode #31427640
# 57: saved episode #31414878
# 58: saved episode #31402214
# 59: saved episode #31389676
# 60: saved episode #31376973
# 61: saved episode #31376972
# 62: saved episode #31364567
# 63: saved episode #31352357
# 64: saved episode #31339824
# 65: saved episode #31339822
# 66: saved episode #31327807
# 67: saved episode #31315691
# 68: saved episode #31303170
# 69: saved episode #31290866
# 70: saved episode #31278768
# 71: saved episode #31266487
# 72: saved episode #31265539
# 73: saved episode #31253517
# 74: saved episode #31241585
# 75: saved episode #31229252
# 76: saved episode #31217120
# 77: saved episode #31205414
# 78: saved episode #31193305
# 79: saved episode #31180609
# 80: saved episode #31168446
# 81: saved episode #31156501
# 82: saved episode #31144629
# 83: saved episode #31132794
# 84: saved episode #31122232
# 85: saved episode #31110271
# 86: saved episode #31098552
# 87: saved episode #31086700
# 88: saved episode #31074860
# 89: saved episode #31063243
# 90: saved episode #31051348
# 91: saved episode #31039449
# 92: saved episode #31027803
# 93: saved episode #31016117
# 94: saved episode #31003896
# 95: saved episode #30992309
# 96: saved episode #30992280
# 97: saved episode #30980459
# 98: saved episode #30968537
# 99: saved episode #30968514
# 100: saved episode #30968513
# 101: saved episode #30968506
# 102: saved episode #30956603
# 103: saved episode #30955408
# 104: saved episode #30943882
# 105: saved episode #30932486
# 106: saved episode #30930829
# 107: saved episode #30919495
# 108: saved episode #30910879
# 109: saved episode #30910878
# 110: saved episode #30899247
# 111: saved episode #30899245
# 112: saved episode #30898186
# 113: saved episode #30888230
# 114: saved episode #30888196
# 115: saved episode #30887129
# 116: saved episode #30876820
# 117: saved episode #30865362
# 118: saved episode #30853773
# 119: saved episode #30842433
# 120: saved episode #30841375
# 121: saved episode #30830690
# 122: saved episode #30819715
# 123: saved episode #30819490
# 124: saved episode #30818828
# 125: saved episode #30818824
# 126: saved episode #30808524
# 127: saved episode #30808253
# 128: saved episode #30808248
# 129: saved episode #30797181
# 130: saved episode #30797174
# 131: saved episode #30790920
# 132: saved episode #30779904
# 133: saved episode #30768688
# 134: saved episode #30757192
# 135: saved episode #30746081
# 136: saved episode #30734925
# 137: saved episode #30734914
# 138: saved episode #30730496
# 139: saved episode #30729149
# 140: saved episode #30727652
# 141: saved episode #30718965
# 142: saved episode #30707961
# 143: saved episode #30707644
# 144: saved episode #30706983
# 145: saved episode #30695821
# 146: saved episode #30685470
# 147: saved episode #30674788
# 148: saved episode #30663945
# 149: saved episode #30653351
# 150: saved episode #30647625
# 151: saved episode #30636276
# 152: saved episode #30624970
# 153: saved episode #30619495
# 154: saved episode #30608581
# 155: saved episode #30597627
# 156: saved episode #30587068
# 157: saved episode #30578042
# 158: saved episode #30577882
# 159: saved episode #30574194
# 160: saved episode #30565747
# 161: saved episode #30554587
# 162: saved episode #30547569
# 163: saved episode #30539681
# 164: saved episode #30531721
# 165: saved episode #30521039
# 166: saved episode #30511123
# 167: saved episode #30501302
# 168: saved episode #30498757
# 169: saved episode #30489095
# 170: saved episode #30486288
# 171: saved episode #30478185
# 172: saved episode #30469611
# 173: saved episode #30468299
# 174: saved episode #30463920
# 175: saved episode #30455762
# 176: saved episode #30447754
# 177: saved episode #30443262
# 178: saved episode #30436159
# 179: saved episode #30429867
# 180: saved episode #30429589
# 181: saved episode #30429311
# 182: saved episode #30429049
# 183: saved episode #30429037
# 184: saved episode #30428762
# 185: saved episode #30428486
# 186: saved episode #30428432
# 187: saved episode #30428207
# 188: saved episode #30427929
# 189: saved episode #30427650
# 190: saved episode #30427369
# 191: saved episode #30427094
# 192: saved episode #30426820
# 193: saved episode #30426546
# 194: saved episode #30426272
# 195: saved episode #30425997
# 196: saved episode #30425722
# 197: saved episode #30425449
# 198: saved episode #30425175
# 199: saved episode #30424900
# 200: saved episode #30424626
# 201: saved episode #30424349
# 202: saved episode #30424071
# 203: saved episode #30423796
# 204: saved episode #30423522
# 205: saved episode #30423247
# 206: saved episode #30422972
# 207: saved episode #30422698
# 208: saved episode #30422424
# 209: saved episode #30422150
# 210: saved episode #30421876
# 211: saved episode #30421602
# 212: saved episode #30421325
# 213: saved episode #30421049
# 214: saved episode #30420774
# 215: saved episode #30420500
# 216: saved episode #30420226
# 217: saved episode #30419952
# 218: saved episode #30419678
# 219: saved episode #30419404
# 220: saved episode #30419130
# 221: saved episode #30418856
# 222: saved episode #30418582
# 223: saved episode #30418308
# 224: saved episode #30418034
# 225: saved episode #30417760
# 226: saved episode #30417487
# 227: saved episode #30417213
# 228: saved episode #30416938
# 229: saved episode #30416663
# 230: saved episode #30415549
#
# submission=23281649, LB=2004, matches=432, still to save=432
# 231: saved episode #32161139
# 232: saved episode #32147455
# 233: saved episode #32133473
# 234: saved episode #32119119
# 235: saved episode #32105349
# 236: saved episode #32091439
# 237: saved episode #32077656
# 238: saved episode #32063908
# 239: saved episode #32049416
# 240: saved episode #32035168
# 241: saved episode #32021390
# 242: saved episode #32007170
# 243: saved episode #31992571
# 244: saved episode #31978919
# 245: saved episode #31965009
# 246: saved episode #31951466
# 247: saved episode #31938264
# 248: saved episode #31924217
# 249: saved episode #31910369
# 250: saved episode #31896892
# 251: saved episode #31883102
# 252: saved episode #31869574
# 253: saved episode #31856318
# 254: saved episode #31843242
# 255: saved episode #31829845
# 256: saved episode #31816479
# 257: saved episode #31802529
# 258: saved episode #31789309
# 259: saved episode #31776779
# 260: saved episode #31763560
# 261: saved episode #31750130
# 262: saved episode #31736962
# 263: saved episode #31723632
# 264: saved episode #31710148
# 265: saved episode #31696689
# 266: saved episode #31683211
# 267: saved episode #31669641
# 268: saved episode #31656441
# 269: saved episode #31644220
# 270: saved episode #31631447
# 271: saved episode #31618973
# 272: saved episode #31606258
# 273: saved episode #31593322
# 274: saved episode #31580165
# 275: saved episode #31567116
# 276: saved episode #31554230
# 277: saved episode #31541676
# 278: saved episode #31528627
# 279: saved episode #31515550
# 280: saved episode #31502811
# 281: saved episode #31489899
# 282: saved episode #31477346
# 283: saved episode #31465035
# 284: saved episode #31452123
# 285: saved episode #31439810
# 286: saved episode #31427516
# 287: saved episode #31414712
# 288: saved episode #31402101
# 289: saved episode #31389545
# 290: saved episode #31376833
# 291: saved episode #31364401
# 292: saved episode #31352191
# 293: saved episode #31339657
# 294: saved episode #31327688
# 295: saved episode #31315566
# 296: saved episode #31303049
# 297: saved episode #31290700
# 298: saved episode #31278633
# 299: saved episode #31266384
# 300: saved episode #31254332
# 301: saved episode #31242370
# 302: saved episode #31230048
# 303: saved episode #31217879
# 304: saved episode #31206176
# 305: saved episode #31194059
# 306: saved episode #31181451
# 307: saved episode #31169163
# 308: saved episode #31157258
# 309: saved episode #31145373
# 310: saved episode #31133516
# 311: saved episode #31121642
# 312: saved episode #31109714
# 313: saved episode #31098025
# 314: saved episode #31086109
# 315: saved episode #31074266
# 316: saved episode #31062595
# 317: saved episode #31050670
# 318: saved episode #31038830
# 319: saved episode #31027198
# 320: saved episode #31015478
# 321: saved episode #31003300
# 322: saved episode #30991690
# 323: saved episode #30979824
# 324: saved episode #30967883
# 325: saved episode #30956011
# 326: saved episode #30944462
# 327: saved episode #30933076
# 328: saved episode #30921739
# 329: saved episode #30910350
# 330: saved episode #30898756
# 331: saved episode #30887721
# 332: saved episode #30876310
# 333: saved episode #30864799
# 334: saved episode #30853254
# 335: saved episode #30841913
# 336: saved episode #30830525
# 337: saved episode #30819314
# 338: saved episode #30808070
# 339: saved episode #30797011
# 340: saved episode #30785953
# 341: saved episode #30774813
# 342: saved episode #30763485
# 343: saved episode #30752108
# 344: saved episode #30741089
# 345: saved episode #30729948
# 346: saved episode #30718607
# 347: saved episode #30707645
# 348: saved episode #30696492
# 349: saved episode #30685469
# 350: saved episode #30674787
# 351: saved episode #30663943
# 352: saved episode #30652924
# 353: saved episode #30641725
# 354: saved episode #30630393
# 355: saved episode #30619240
# 356: saved episode #30608329
# 357: saved episode #30597378
# 358: saved episode #30586825
# 359: saved episode #30576169
# 360: saved episode #30565462
# 361: saved episode #30554312
# 362: saved episode #30543383
# 363: saved episode #30532439
# 364: saved episode #30521655
# 365: saved episode #30511278
# 366: saved episode #30500832
# 367: saved episode #30490332
# 368: saved episode #30479722
# 369: saved episode #30469243
# 370: saved episode #30458741
# 371: saved episode #30447744
# 372: saved episode #30436914
# 373: saved episode #30426146
# 374: saved episode #30415692
# 375: saved episode #30405244
# 376: saved episode #30394559
# 377: saved episode #30383947
# 378: saved episode #30373559
# 379: saved episode #30362876
# 380: saved episode #30351972
# 381: saved episode #30341543
# 382: saved episode #30331048
# 383: saved episode #30320377
# 384: saved episode #30310182
# 385: saved episode #30299763
# 386: saved episode #30289263
# 387: saved episode #30278924
# 388: saved episode #30268497
# 389: saved episode #30258374
# 390: saved episode #30248082
# 391: saved episode #30237327
# 392: saved episode #30226857
# 393: saved episode #30216732
# 394: saved episode #30206569
# 395: saved episode #30196269
# 396: saved episode #30186129
# 397: saved episode #30175949
# 398: saved episode #30165886
# 399: saved episode #30155484
# 400: saved episode #30145231
# 401: saved episode #30134940
# 402: saved episode #30124926
# 403: saved episode #30115015
# 404: saved episode #30104760
# 405: saved episode #30094508
# 406: saved episode #30084251
# 407: saved episode #30073873
# 408: saved episode #30063511
# 409: saved episode #30053307
# 410: saved episode #30042905
# 411: saved episode #30032983
# 412: saved episode #30022870
# 413: saved episode #30012394
# 414: saved episode #30001939
# 415: saved episode #29991742
# 416: saved episode #29981634
# 417: saved episode #29971313
# 418: saved episode #29960946
# 419: saved episode #29951066
# 420: saved episode #29941133
# 421: saved episode #29931131
# 422: saved episode #29921060
# 423: saved episode #29910994
# 424: saved episode #29901315
# 425: saved episode #29891627
# 426: saved episode #29881687
# 427: saved episode #29871801
# 428: saved episode #29861759
# 429: saved episode #29851658
# 430: saved episode #29841739
# 431: saved episode #29831931
# 432: saved episode #29822074
# 433: saved episode #29812512
# 434: saved episode #29802760
# 435: saved episode #29792682
# 436: saved episode #29782770
# 437: saved episode #29772538
# 438: saved episode #29762294
# 439: saved episode #29752494
# 440: saved episode #29742538
# 441: saved episode #29732569
# 442: saved episode #29723103
# 443: saved episode #29713917
# 444: saved episode #29704374
# 445: saved episode #29694523
# 446: saved episode #29684782
# 447: saved episode #29675289
# 448: saved episode #29665760
# 449: saved episode #29656381
# 450: saved episode #29646506
# 451: saved episode #29636835
# 452: saved episode #29626248
# 453: saved episode #29616591
# 454: saved episode #29607171
# 455: saved episode #29597779
# 456: saved episode #29588162
# 457: saved episode #29578636
# 458: saved episode #29569227
# 459: saved episode #29559654
# 460: saved episode #29550071
# 461: saved episode #29540391
# 462: saved episode #29530899
# 463: saved episode #29521533
# 464: saved episode #29512440
# 465: saved episode #29503192
# 466: saved episode #29493943
# 467: saved episode #29484770
# 468: saved episode #29475261
# 469: saved episode #29465910
# 470: saved episode #29456187
# 471: saved episode #29447153
# 472: saved episode #29438394
# 473: saved episode #29429291
# 474: saved episode #29420025
# 475: saved episode #29410817
# 476: saved episode #29401814
# 477: saved episode #29392879
# 478: saved episode #29383949
# 479: saved episode #29374592
# 480: saved episode #29365157
# 481: saved episode #29356097
# 482: saved episode #29347015
# 483: saved episode #29337827
# 484: saved episode #29328982
# 485: saved episode #29319991
# 486: saved episode #29311048
# 487: saved episode #29302079
# 488: saved episode #29293123
# 489: saved episode #29284164
# 490: saved episode #29275286
# 491: saved episode #29266531
# 492: saved episode #29257410
# 493: saved episode #29248396
# 494: saved episode #29239603
# 495: saved episode #29230494
# 496: saved episode #29221665
# 497: saved episode #29212822
# 498: saved episode #29203824
# 499: saved episode #29194973
# 500: saved episode #29186271
# 501: saved episode #29177321
# 502: saved episode #29167701
# 503: saved episode #29159228
# 504: saved episode #29150378
# 505: saved episode #29141437
# 506: saved episode #29132272
# 507: saved episode #29122544
# 508: saved episode #29113920
# 509: saved episode #29105359
# 510: saved episode #29096691
# 511: saved episode #29087875
# 512: saved episode #29079471
# 513: saved episode #29071081
# 514: saved episode #29062617
# 515: saved episode #29054124
# 516: saved episode #29045430
# 517: saved episode #29037048
# 518: saved episode #29028785
# 519: saved episode #29028737
# 520: saved episode #29020285
# 521: saved episode #29020271
# 522: saved episode #29011667
# 523: saved episode #29003388
# 524: saved episode #28995107
# 525: saved episode #28986467
# 526: saved episode #28977787
# 527: saved episode #28969263
# 528: saved episode #28961039
# 529: saved episode #28952416
# 530: saved episode #28944033
# 531: saved episode #28926406
# 532: saved episode #28917640
# 533: saved episode #28908917
# 534: saved episode #28900421
# 535: saved episode #28891910
# 536: saved episode #28883711
# 537: saved episode #28875651
# 538: saved episode #28867441
# 539: saved episode #28859187
# 540: saved episode #28850759
# 541: saved episode #28842347
# 542: saved episode #28842287
# 543: saved episode #28833672
# 544: saved episode #28825750
# 545: saved episode #28817763
# 546: saved episode #28809722
# 547: saved episode #28801769
# 548: saved episode #28793688
# 549: saved episode #28785595
# 550: saved episode #28777608
# 551: saved episode #28769538
# 552: saved episode #28761136
# 553: saved episode #28752940
# 554: saved episode #28744365
# 555: saved episode #28744351
# 556: saved episode #28736095
# 557: saved episode #28728007
# 558: saved episode #28719723
# 559: saved episode #28711508
# 560: saved episode #28703600
# 561: saved episode #28695434
# 562: saved episode #28695378
# 563: saved episode #28687175
# 564: saved episode #28682329
# 565: saved episode #28665466
# 566: saved episode #28657503
# 567: saved episode #28649682
# 568: saved episode #28641726
# 569: saved episode #28633643
# 570: saved episode #28625738
# 571: saved episode #28617795
# 572: saved episode #28609549
# 573: saved episode #28601481
# 574: saved episode #28600927
# 575: saved episode #28592757
# 576: saved episode #28589707
# 577: saved episode #28582371
# 578: saved episode #28574442
# 579: saved episode #28566452
# 580: saved episode #28558267
# 581: saved episode #28556149
# 582: saved episode #28549623
# 583: saved episode #28541681
# 584: saved episode #28533832
# 585: saved episode #28526325
# 586: saved episode #28523084
# 587: saved episode #28518070
# 588: saved episode #28511851
# 589: saved episode #28507611
# 590: saved episode #28507573
# 591: saved episode #28499755
# 592: saved episode #28496033
# 593: saved episode #28496032
# 594: saved episode #28494869
# 595: saved episode #28487185
# 596: saved episode #28486990
# 597: saved episode #28479221
# 598: saved episode #28471746
# 599: saved episode #28468853
# 600: saved episode #28463955
# 601: saved episode #28463615
# 602: saved episode #28456338
# 603: saved episode #28455645
# 604: saved episode #28450923
# 605: saved episode #28445553
# 606: saved episode #28439950
# 607: saved episode #28439912
# 608: saved episode #28433785
# 609: saved episode #28430589
# 610: saved episode #28429082
# 611: saved episode #28428262
# 612: saved episode #28427052
# 613: saved episode #28426164
# 614: saved episode #28425148
# 615: saved episode #28421028
# 616: saved episode #28417013
# 617: saved episode #28416814
# 618: saved episode #28416624
# 619: saved episode #28416434
# 620: saved episode #28416242
# 621: saved episode #28416052
# 622: saved episode #28415861
# 623: saved episode #28415661
# 624: saved episode #28415469
# 625: saved episode #28415279
# 626: saved episode #28415088
# 627: saved episode #28414898
# 628: saved episode #28414706
# 629: saved episode #28414515
# 630: saved episode #28414324
# 631: saved episode #28414134
# 632: saved episode #28413943
# 633: saved episode #28413754
# 634: saved episode #28413564
# 635: saved episode #28413372
# 636: saved episode #28413179
# 637: saved episode #28412988
# 638: saved episode #28412796
# 639: saved episode #28412606
# 640: saved episode #28412417
# 641: saved episode #28412225
# 642: saved episode #28412035
# 643: saved episode #28411841
# 644: saved episode #28411641
# 645: saved episode #28411445
# 646: saved episode #28411254
# 647: saved episode #28411065
# 648: saved episode #28410873
# 649: saved episode #28410681
# 650: saved episode #28410492
# 651: saved episode #28410303
# 652: saved episode #28410114
# 653: saved episode #28409925
# 654: saved episode #28409735
# 655: saved episode #28409545
# 656: saved episode #28409355
# 657: saved episode #28409165
# 658: saved episode #28408973
# 659: saved episode #28408782
# 660: saved episode #28408593
# 661: saved episode #28408404
# 662: saved episode #28407441
#
# Episodes saved: 663
